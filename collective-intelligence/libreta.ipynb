# %% [markdown]
# # Búsqueda y ranqueo de páginas web
#
# Este documento presenta una revisión y reimplementación del buscador de páginas web desarrollado en el capítulo 4 del *libro Programming Collective Intelligence*.
#
# ## Diseño del buscador
#
# ## Implementación
#
# ### Módulos
#
# Se utilizarán algunon módulos de Python que facilitará la implementación del buscador, en particular con el almacenamiento de la información (bases de datos) y la recolección e interpretación de las páginas web (descarga y parseo de documentos HTML).

# %%
import urllib2
from bs4 import*
from urlparse import urljoin
from sqlite3 import dbapi2 as sqlite
import re

# %% [markdown]
# ### Información de prueba
#
# Se diseñó el sitio web http://eduardoacye.github.io para realizar las pruebas del buscador implementado y se utilizan las *stop words* en español del sitio https://code.google.com/p/stop-words/

# %%
test_urls = ["http://eduardoacye.github.io"]
test_db   = "searchindex.db"
ignore_words = set([line.strip() for line in
                    open("stop-words/stop-words_spanish_1_es.txt", "r")]
                   +
                   [line.strip() for line in
                    open("stop-words/stop-words_spanish_2_es.txt", "r")])

# %% [markdown]
# ### Funciones para el indexado
#
# #### get_page
#
# - `url` es una cadena de caracteres.
#
# Regresa el contenido y la codificación de la página asociada a la URL

# %%
def get_page(url):
    try:
        resource = urllib2.urlopen(url)
    except:
        raise Exception("Could not open %s" % url)
    encoding = resource.headers["content-type"].split("charset=")[-1]
    content = unicode(resource.read(), encoding)
    return content, encoding

# %% [markdown]
# #### parse_page
#
# - `content` es una cadena unicode cuyo contenido son los caracteres que conforman a una página en HTML.
#
# Regresa un objeto BeautifulSoup que representa el HTML parseado.

# %%
def parse_page(content):
    html_tree = BeautifulSoup(content)
    return html_tree

# %% [markdown]
# #### has_href
#
# - `link` es un objeto `BeautifulSoup.Tag`.
#
# Regresa un booleano determinando si el enlace contiene un atributo href.

# %%
def has_href(link):
    return "href" in link.attrs

# %% [markdown]
# #### link_url
#
# - `base_url` es una cadena de caracteres que representa una URL.
# - `link` es un objeto BeautifulSoup.Tag.
#
# Regresa una cadena de caracteres que representa la URL del enlace.

# %%
def link_url(base_url, link):
    url = urljoin(base_url, link["href"])
    if url.find("'") != -1:
        raise Exception("Malformed URL %s" % url)
    url = url.split("#")[0]
    return url

# %% [markdown]
# #### is_http
#
# - `url` es una cadena de caracteres que representa una URL.
#
# Regresa un booleano determinando si el recurso web que indica la URL es
# una página web.

# %%
def is_http(url):
    return url[0:4] == "http"

# %% [markdown]
# #### db_connect
#
# - `db_name` es una cadena de caracteres que representa el nombre de la base de una base de datos.
#
# Regresa una conexión a la base de datos especificada por el nombre.

# %%
def db_connect(db_name):
    return sqlite.connect(db_name)

# %% [markdown]
# #### db_close
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
#
# Cierra la conexión con la base de datos.

# %%
def db_close(connection):
    connection.close()

# %% [markdown]
# #### db_commit
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
#
# Guarda en la base de datos los cambios realizados.

# %%
def db_commit(connection):
    connection.commit()

# %% [markdown]
# #### db_create_tables
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
#
# Crea las tablas de la base de datos correspondientes a la funcionalidad
# del crawler.

# %%
def db_create_tables(connection):
    connection.execute("create table urllist(url)")
    connection.execute("create table wordlist(word)")
    connection.execute("create table wordlocation(urlid, wordid, location)")
    connection.execute("create table link(fromid integer, toid integer)")
    connection.execute("create table linkwords(wordid, linkid)")
    connection.execute("create index wordidx on wordlist(word)")
    connection.execute("create index urlidx on urllist(url)")
    connection.execute("create index wordurlidx on wordlocation(wordid)")
    connection.execute("create index urltoidx on link(toid)")
    connection.execute("create index urlfromidx on link(fromid)")
    db_commit(connection)

# %% [markdown]
# #### db_get_table y db_get_tables
#
# **Para db_get_table:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# -`table` es una cadena de caracteres que representa el nombre de la tabla en la base de datos.
#
# Regresa una lista con el contenido de la tabla especificada.
#
# **Para db_get_tables:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
#
# Regresa una tupla con listas con el contenido de cada tabla en la base de datos.

# %%
def db_get_table(connection, table):
    table = connection.execute("select * from %s" % table)
    return table.fetchall()

def db_get_tables(connection):
    return (db_get_table(connection, "urllist"),
            db_get_table(connection, "wordlist"),
            db_get_table(connection, "wordlocation"),
            db_get_table(connection, "link"),
            db_get_table(connection, "linkwords"))

# %% [markdown]
# #### is_indexed
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# - `url` es una cadena de caracteres que representa una URL.
#
# Regresa un booleano que determina si la URL ya fué inspeccionada por el crawler.

# %%
def is_indexed(connection, url):
    table = connection.execute("select rowid from urllist where url='%s'" % url)
    result = table.fetchone()
    if result is not None:
        url_id = connection.execute("select * from wordlocation where urlid = %d"
                                    % result[0]).fetchone()
        if url_id is not None:
            return True
    return False

# %% [markdown]
# #### strip_html_tags
#
# - `html` es un objeto `BeautifulSoup`.
#
# Regresa una cadena unicode con el contenido del HTML sin las etiquetas.

# %%
def strip_html_tags(html):
    html_inside_tag = html.string
    if html_inside_tag is None:
        resulting_text = ""
        for tag in html.contents:
            sub_text = strip_html_tags(tag)
            resulting_text += sub_text + "\n"
        return resulting_text
    else:
        return html_inside_tag.strip()

# %% [markdown]
# #### separate_words
#
# - `text` es una cadena unicode que representa algún texto.
#
# Regresa una lista con las palabras del texto.

# %%
def separate_words(text):
    splitter = re.compile(ur"\W*", re.UNICODE)
    splitted = splitter.split(text)
    return [s.lower() for s in splitted if s != ""]

# %% [markdown]
# #### select_entry_id
#
# - `connection` es un obteto obtenido con una llamada a `db_connect`.
# - `table` es una cadena de caracteres que representa el nombre de una tabla de la base de datos.
# - `column` es una cadena de caracteres que representa el nombre de una columna de la tabla especificada de la base de datos.
# - `value`. es un valor que puede estar almacenado en la columna especificada de la tabla especificada de la base de datos.
#
# Regresa `None` si no se encontró una entrada con el valor en la columna de la tabla, de lo contrario se regresa el id de la entrada.

# %%
def select_entry_id(connection, table, column, value):
    table = connection.execute("select rowid from %s where %s = '%s'"
                               % (table, column, value))
    result = table.fetchone()
    if result is None:
        return result
    else:
        return result[0]

# %% [markdown]
# #### insert_entry
#
# - `connection` es un obteto obtenido con una llamada a `db_connect`.
# - `table` es una cadena de caracteres que representa el nombre de una tabla de la base de datos.
# - `column` es una cadena de caracteres que representa el nombre de una columna de la tabla especificada de la base de datos.
# - `value` es un valor que puede estar almacenado en la columna especificada de la tabla especificada de la base de datos.
#
# Crea una nueva entrada en la tabla especificada con el valor dado en la columna especificada.

# %%
def insert_entry(connection, table, column, value):
    table = connection.execute("insert into %s (%s) values ('%s')"
                               % (table, column, value))
    return table.lastrowid

# %% [markdown]
# #### index_page_words y index_page
#
# **Para index_page_words:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# - `url_id` es un id de la base de datos que está asociada a una página web.
# - `words` es una lista de palabras.
#
# Relaciona las palabras con la URL en la base de datos.
#
# **Para index_page:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# - `url` es una cadena de caracteres que representa una URL.
# - `html` es un objeto `BeautifulSoup`.
#
# Procesa el documento de HTML para relacionar las palabras en el
# documento con la URL.

# %%
def index_page_words(connection, url_id, words):
    print "      INDEXING WORDS FROM URL ID %s" % url_id
    for i in range(len(words)):
        word = words[i]
        if word in ignore_words:
            continue
        word_id = select_entry_id(connection, "wordlist", "word", word)
        if word_id is None:
            print "        %s" % word
            insert_entry(connection, "wordlist", "word", word)
            word_id = select_entry_id(connection, "wordlist", "word", word)
        connection.execute("insert into wordlocation(urlid, wordid, location) values (%d,%d,%d)"
                           % (url_id, word_id, i))

def index_page(connection, url, html):
    if is_indexed(connection, url):
        return
    print "    INDEXING %s" % url
    text = strip_html_tags(html)
    words = separate_words(text)

    url_id = select_entry_id(connection, "urllist", "url", url)
    if url_id is None:
        insert_entry(connection, "urllist", "url", url)
        url_id = select_entry_id(connection, "urllist", "url", url)
    index_page_words(connection, url_id, words)
    print "      INDEXED! %s" % url

# %% [markdown]
# #### index_link_words y index_link
#
# **Para index_link_words:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# - `link_id` es un id de la base de datos que está asociada a enlace.
# - `words` es una lista de palabras.
#
# Relaciona las palabras con el enlace en la base de datos.
#
# **Para index_link:**
#
# - `connection` es un objeto obtenido con una llamada a `db_connect`.
# - `from_url` es una cadena de caracteres que representa una URL.
# - `to_url` es una cadena de caracteres que representa una URL.
# - `link` es un objeto `BeautifulSoup.Tag`.
#
# Procesa la etiqueta de HTML <a...>...</a> para relacionar las palabras en el enlace con las URLs involucradas.

# %%
def index_link_words(connection, link_id, words):
    for word in words:
        if word in ignore_words:
            continue
        word_id = select_entry_id(connection, "wordlist", "word", word)
        if word_id is None:
            print "        PALABRA %s" % word
            insert_entry(connection, "wordlist", "word", word)
            word_id = select_entry_id(connection, "wordlist", "word", word)
        connection.execute("insert into linkwords(wordid, linkid) values (%d,%d)"
                           % (word_id, link_id))

def index_link(connection, from_url, to_url, link):
    text = strip_html_tags(link)
    words = separate_words(text)

    from_url_id = select_entry_id(connection, "urllist", "url", from_url)
    if from_url_id is None:
        insert_entry(connection, "urllist", "url", from_url)
        from_url_id = select_entry_id(connection, "urllist", "url", from_url)
    to_url_id = select_entry_id(connection, "urllist", "url", to_url)
    if to_url_id is None:
        insert_entry(connection, "urllist", "url", to_url)
        to_url_id = select_entry_id(connection, "urllist", "url", to_url)

    if from_url_id == to_url_id:
        return
    table = connection.execute("insert into link (fromid, toid) values (%d,%d)"
                               % (from_url_id, to_url_id))
    link_id = table.lastrowid
    index_link_words(connection, link_id, words)

# %% [markdown]
# #### crawl
#
# - `urls` es una lista de cadenas de caracteres que representan URLs.
# - `connection` es un objeto obtenido con una llamada `db_connect`.
# - `depth` es un entero positivo que representa la profundidad a la que se procesarán las páginas (similar a la profundidad de una búsqueda en grafos).
#
# Navega por páginas web a partir de la lista de URLs dada, procesando palabras y enlaces.

# %%
def crawl(urls, connection, depth=2):
    print "CRAWL"
    for i in range(depth):
        print "  DEPTH %d" % i
        new_urls = set()
        print "  URLs %s" % urls
        for url in urls:
            content, encoding = get_page(url)
            html = parse_page(content)
            print "    VISITED %s" % url
            index_page(connection, url, html)

            links = html.select("a")
            for link in links:
                if has_href(link):
                    ref_url = link_url(url, link)
                    if is_http(ref_url) and not is_indexed(connection, ref_url):
                        new_urls.add(ref_url)
                    index_link(connection, url, ref_url, link)
        urls = list(new_urls)

# %% [markdown]
# ### Prueba de indexado
#
# Ahora se va a correr el crawler con las URLs de prueba. Al terminar de computar los procedimientos de `index_test_urls` se tendrá una base de datos llamada `searchindex.db` con la información del indexado almacenada.

# %%
def index_test_urls():
    connection = db_connect(test_db)
    db_create_tables(connection)
    crawl(test_urls, connection, depth=10)
    db_close(connection)

# %%
index_test_urls()
# Out:
# CRAWL
#   DEPTH 0
#   URLs ['http://eduardoacye.github.io']
#     VISITED http://eduardoacye.github.io
#     INDEXING http://eduardoacye.github.io
#       INDEXING WORDS FROM URL ID 1
#         html
#         tópicos
#         avanzados
#         ia
#         página
#         oficial
#         curso
#         href
#         pagina
#         malhechora
#         mal
#         información
#         través
#         piazza
#         conducir
#         desarrollo
#         dudas
#         sugerencias
#         temas
#         desarrollaremos
#         seminario
#         recuerden
#         materia
#         más
#         iniciativa
#         espíritu
#         crítico
#         colaboración
#         habilidades
#         espera
#         promover
#         tipo
#         materias
#         favor
#         hagan
#         extensivo
#         medio
#         comuniquemos
#         ideas
#         documentos
#         enlaces
#         código
#         material
#         enriquezca
#         discusión
#         igualmente
#         deberían
#         canalizadas
#         así
#         proponer
#         soluciones
#         modificaciones
#         proyectos
#         dinámica
#         seleccionando
#         serie
#         interés
#         área
#         tema
#         seleccionado
#         seleccionar
#         capítulo
#         libro
#         blog
#         tutorial
#         artículo
#         proyecto
#         señe
#         principios
#         básicos
#         aplique
#         pequeño
#         concreto
#         anexo
#         documento
#         principal
#         incluirán
#         técnicos
#         teóricos
#         prácticos
#         permitan
#         complementar
#         idea
#         fijarnos
#         establecido
#         desarrollarlo
#         comentarlos
#         modificación
#         permita
#         comprensión
#         listado
#         métodos
#         ranking
#         sistemas
#         recomendación
#         lógica
#         difusa
#         aprendizaje
#         profundo
#         filtros
#         partículas
#         refuerzo
#         participantes
#         chunkzer
#         cruzluquejm
#         d4c1
#         eduardoacye
#         rafaextremist
#         geraterra
#         juliowaissman
#       INDEXED! http://eduardoacye.github.io
#   DEPTH 1
#   URLs ['http://eduardoacye.github.io/participantes/luque.html', 'http://eduardoacye.github.io/proyectos/fuzzy.html', 'http://eduardoacye.github.io/participantes/eduardo.html', 'http://eduardoacye.github.io/proyectos/ranking.html', 'http://eduardoacye.github.io/proyectos/reinforcement.html', 'http://eduardoacye.github.io/participantes/rafa.html', 'http://eduardoacye.github.io/participantes/waiss.html', 'http://eduardoacye.github.io/participantes/gera.html', 'http://eduardoacye.github.io/participantes/ruink.html', 'http://eduardoacye.github.io/proyectos/particle.html', 'http://eduardoacye.github.io/proyectos/recomend.html', 'http://eduardoacye.github.io/proyectos/deep.html', 'http://eduardoacye.github.io/participantes/mois.html']
#     VISITED http://eduardoacye.github.io/participantes/luque.html
#     INDEXING http://eduardoacye.github.io/participantes/luque.html
#       INDEXING WORDS FROM URL ID 9
#         juan
#         manuel
#         cruz
#         luque
#       INDEXED! http://eduardoacye.github.io/participantes/luque.html
#     VISITED http://eduardoacye.github.io/proyectos/fuzzy.html
#     INDEXING http://eduardoacye.github.io/proyectos/fuzzy.html
#       INDEXING WORDS FROM URL ID 4
#         encargado
#         asignado
#         también
#         llamada
#         borrosa
#         basa
#         relativo
#         observado
#         posición
#         diferencial
#         toma
#         valores
#         aleatorios
#         contextualizados
#         referidos
#         sí
#         persona
#         mida
#         metros
#         claramente
#         alta
#         previamente
#         tomado
#         baja
#         metro
#         están
#         personas
#         medida
#         métrica
#         lineal
#         размитата
#         логика
#         английски
#         fuzzy
#         logic
#         е
#         форма
#         на
#         многовариационна
#         произлизаща
#         от
#         тероията
#         размитите
#         множества
#         с
#         цел
#         да
#         отрази
#         това
#         което
#         относително
#         а
#         не
#         точно
#         в
#         сравнение
#         множествата
#         двоичната
#         логиката
#         борави
#         променливи
#         които
#         могат
#         бъдат
#         със
#         стойности
#         между
#         0
#         и
#         1
#         ограничена
#         единствено
#         до
#         истинни
#         истина
#         лъжа
#         така
#         както
#         класическата
#         ファジィ論理
#         ファジィろんり
#         英
#         は
#         1965年
#         カリフォルニア大学バークレー校のロトフィ
#         ザデーが生み出したファジィ集合から派生した
#         2
#         多値論理の一種で
#         真理値が0から1までの範囲の値をとり
#         古典論理のように
#         真
#         と
#         偽
#         という2つの値に限定されない
#         3
#         ことが特徴である
#         さらにlinguistic
#         variablesは
#         数値ではなく
#         言語学的
#         linguistic
#         な値をとる変数
#         variables
#         である
#         ファジィ論理は制御理論
#         ファジィ制御
#         から人工知能まで様々な分野に応用されている
#         ဖပ
#         ဇ
#         လ
#         ဂ
#         စ
#         ဆ
#         သည
#         မ
#         တန
#         ဖ
#         အမ
#         အပ
#         က
#         ရည
#         ည
#         န
#         ပ
#         သ
#         အစ
#         တစ
#         အသ
#         ထ
#         ခ
#         င
#         အတ
#         အက
#         မဟ
#         တ
#         ဘ
#         ခန
#         သပ
#         ရသ
#         ရ
#         နရ
#         တည
#         ပင
#         တဝက
#         တပ
#         ဝ
#         ဝမ
#         ယ
#         ရန
#       INDEXED! http://eduardoacye.github.io/proyectos/fuzzy.html
#     VISITED http://eduardoacye.github.io/participantes/eduardo.html
#     INDEXING http://eduardoacye.github.io/participantes/eduardo.html
#       INDEXING WORDS FROM URL ID 11
#         eduardo
#         acuña
#         yeomans
#       INDEXED! http://eduardoacye.github.io/participantes/eduardo.html
#     VISITED http://eduardoacye.github.io/proyectos/ranking.html
#     INDEXING http://eduardoacye.github.io/proyectos/ranking.html
#       INDEXING WORDS FROM URL ID 2
#         pagerank
#         is
#         an
#         algorithm
#         used
#         by
#         google
#         search
#         to
#         rank
#         websites
#         in
#         their
#         engine
#         results
#         was
#         named
#         after
#         larry
#         page
#         one
#         of
#         the
#         founders
#         way
#         measuring
#         importance
#         website
#         pages
#         marca
#         registrada
#         patentada1
#         9
#         enero
#         1999
#         ampara
#         familia
#         algoritmos
#         utilizados
#         asignar
#         forma
#         numérica
#         relevancia
#         páginas
#         web
#         indexados
#         motor
#         búsqueda
#         propiedades
#         discutidas
#         expertos
#         optimización
#         motores
#         sistema
#         utilizado
#         popular
#         ayudarle
#         determinar
#         importancia
#         desarrollado
#         fundadores
#         apellido
#         recibe
#         nombre
#         algoritmo
#         sergey
#         brin
#         universidad
#         stanford
#         estudiaban
#         posgrado
#         ciencias
#         computación
#         网页排名
#         又称网页级别
#         google左侧排名或佩奇排名
#         是一种由搜索引擎根据网页之间相互的超链接计算的技術
#         而作为网页排名的要素之一
#         以google公司創辦人拉里
#         佩奇
#         之姓來命名
#         google用它来体现网页的相关性和重要性
#         在搜索引擎优化操作中是經常被用來評估網頁優化的成效因素之一
#         google的创始人拉里
#         佩奇和谢尔盖
#         布林於1998年在斯坦福大学发明了这项技术
#         пэйдж
#         ранк
#         один
#         из
#         алгоритмов
#         ссылочного
#         ранжирования
#         алгоритм
#         применяется
#         к
#         коллекции
#         документов
#         связанных
#         гиперссылками
#         таких
#         как
#         веб
#         страницы
#         всемирной
#         паутины
#         назначает
#         каждому
#         них
#         некоторое
#         численное
#         значение
#         измеряющее
#         его
#         важность
#         или
#       INDEXED! http://eduardoacye.github.io/proyectos/ranking.html
#     VISITED http://eduardoacye.github.io/proyectos/reinforcement.html
#     INDEXING http://eduardoacye.github.io/proyectos/reinforcement.html
#       INDEXING WORDS FROM URL ID 7
#         reinforcement
#         learning
#         area
#         machine
#         inspired
#         behaviorist
#         psychology
#         concerned
#         with
#         how
#         software
#         agents
#         ought
#         take
#         actions
#         environment
#         so
#         as
#         maximize
#         some
#         notion
#         cumulative
#         reward
#         problem
#         due
#         its
#         generality
#         studied
#         many
#         other
#         disciplines
#         such
#         game
#         theory
#         control
#         operations
#         research
#         information
#         simulation
#         based
#         optimization
#         multi
#         agent
#         systems
#         swarm
#         intelligence
#         statistics
#         and
#         genetic
#         algorithms
#         literature
#         field
#         where
#         methods
#         are
#         called
#         approximate
#         dynamic
#         programming
#         has
#         been
#         optimal
#         though
#         most
#         studies
#         existence
#         solutions
#         characterization
#         not
#         or
#         approximation
#         aspects
#         economics
#         may
#         be
#         explain
#         equilibrium
#         arise
#         under
#         bounded
#         rationality
#         контекста
#         изкуствения
#         интелект
#         терминът
#         обучение
#         утвърждение
#         анг
#         обозначава
#         група
#         методи
#         за
#         автоматично
#         самообучение
#         тези
#         се
#         отличават
#         способността
#         си
#         функционират
#         без
#         необходимост
#         примерни
#         решения
#         поставения
#         проблем
#         обучението
#         протича
#         като
#         последователност
#         пробни
#         действия
#         постепенно
#         водят
#         утвърждаване
#         добрите
#         избягване
#         неподходящите
#         η
#         ενισχυτική
#         μάθηση
#         στην
#         επιστήμη
#         των
#         υπολογιστών
#         είναι
#         ένας
#         γενικός
#         όρος
#         που
#         έχει
#         δοθεί
#         σε
#         μια
#         οικογένεια
#         τεχνικών
#         στις
#         οποίες
#         το
#         σύστημα
#         μάθησης
#         προσπαθεί
#         να
#         μάθει
#         μέσα
#         από
#         την
#         άμεση
#         αλληλεπίδραση
#         με
#         περιβάλλον
#         εφαρμόζεται
#         στον
#         έλεγχο
#         κίνησης
#         ρομπότ
#         στη
#         βελτιστοποίηση
#         εργασιών
#         εργοστάσια
#         επιτραπέζιων
#         παιχνιδιών
#         κτλ
#         έννοια
#         της
#         ενισχυτικής
#         εμπνευσμένη
#         τα
#         αντίστοιχα
#         ανάλογα
#         επιβράβευση
#         και
#         τιμωρία
#         συναντώνται
#         ως
#         μοντέλα
#         έμβιων
#         όντων
#         σκοπός
#         του
#         συστήματος
#         μεγιστοποιήσει
#         συνάρτηση
#         αριθμητικού
#         σήματος
#         ενίσχυσης
#         ανταμοιβή
#         για
#         παράδειγμα
#         αναμενόμενη
#         τιμή
#         στο
#         επόμενο
#         βήμα
#         δεν
#         καθοδηγείται
#         κάποιον
#         εξωτερικό
#         επιβλέποντα
#         ποια
#         ενέργεια
#         θα
#         πρέπει
#         ακολουθήσει
#         αλλά
#         ανακαλύψει
#         μόνο
#         ποιες
#         ενέργειες
#         αυτές
#         αποφέρουν
#         μεγαλύτερο
#         κέρδος
#         מודל
#         הלמידה
#         באמצעות
#         חיזוקים
#         מבוסס
#         על
#         למידה
#         מתוך
#         ניסוי
#         וטעיה
#         שמתבצעת
#         בסדרת
#         אינטראקציות
#         בין
#         סוכן
#         לומד
#         רכיב
#         תוכנה
#         או
#         רובוט
#         לבין
#         סביבתו
#         המיוצגת
#         כמידע
#         חושי
#         סנסורי
#         הזמין
#         לסוכן
#         הלומד
#         בכל
#         אינטראקציה
#         כזאת
#         מקבל
#         הסוכן
#         מידע
#         מסביבתו
#         לגבי
#         המצב
#         הנתון
#         ובוחר
#         לבצע
#         פעולה
#         ממרחב
#         הפעולות
#         לו
#         בהתאם
#         למדיניות
#         הפעולה
#         הנוכחית
#         בתגובה
#         מתקבל
#         אות
#         תגמול
#         שהוא
#         ערך
#         מספרי
#         המבטא
#         את
#         חיוניות
#         למצב
#         ועל
#         פיו
#         מעדכן
#         מדיניותו
#         עבור
#         האינטראקציות
#         הבאות
#         מטרתו
#         של
#         היא
#         לגבש
#         מדיניות
#         הממפה
#         מרחב
#         המצבים
#         האפשריים
#         למרחב
#         כך
#         שהתגמול
#         הכולל
#         המבוטא
#         כסכום
#         משוקלל
#         אותות
#         התגמול
#         שהתקבלו
#         החל
#         מתחילת
#         הניסוי
#         ביצוע
#         פעולות
#         סמך
#         זו
#         יהיה
#         גבוה
#         ככל
#         שניתן
#       INDEXED! http://eduardoacye.github.io/proyectos/reinforcement.html
#     VISITED http://eduardoacye.github.io/participantes/rafa.html
#     INDEXING http://eduardoacye.github.io/participantes/rafa.html
#       INDEXING WORDS FROM URL ID 12
#         rafael
#         noriega
#       INDEXED! http://eduardoacye.github.io/participantes/rafa.html
#     VISITED http://eduardoacye.github.io/participantes/waiss.html
#     INDEXING http://eduardoacye.github.io/participantes/waiss.html
#       INDEXING WORDS FROM URL ID 14
#         julio
#         waissman
#         vilanova
#       INDEXED! http://eduardoacye.github.io/participantes/waiss.html
#     VISITED http://eduardoacye.github.io/participantes/gera.html
#     INDEXING http://eduardoacye.github.io/participantes/gera.html
#       INDEXING WORDS FROM URL ID 13
#         gerardo
#         tarragona
#       INDEXED! http://eduardoacye.github.io/participantes/gera.html
#     VISITED http://eduardoacye.github.io/participantes/ruink.html
#     INDEXING http://eduardoacye.github.io/participantes/ruink.html
#       INDEXING WORDS FROM URL ID 8
#         christian
#         ruink
#       INDEXED! http://eduardoacye.github.io/participantes/ruink.html
#     VISITED http://eduardoacye.github.io/proyectos/particle.html
#     INDEXING http://eduardoacye.github.io/proyectos/particle.html
#       INDEXING WORDS FROM URL ID 6
#         encargadono
#         particle
#         filters
#         sequential
#         monte
#         carlo
#         smc
#         set
#         type
#         methodologies
#         solve
#         filtering
#         term
#         first
#         coined
#         1996
#         moral
#         reference
#         mean
#         interacting
#         fluid
#         mechanics
#         since
#         beginning
#         1960s
#         terminology
#         proposed
#         liu
#         chen
#         1998
#         filtres
#         particulaires
#         sont
#         généralement
#         utilisés
#         pour
#         estimer
#         des
#         réseaux
#         bayésiens
#         et
#         constituent
#         méthodes
#         ligne
#         analogues
#         aux
#         par
#         chaînes
#         markov
#         qui
#         elles
#         hors
#         donc
#         posteriori
#         souvent
#         similaires
#         d
#         échantillonnage
#         この手法はふつうベイズモデルを推定するのに用いられ
#         バッチ処理であるマルコフ連鎖モンテカルロ法
#         mcmc
#         の逐次
#         オンライン
#         版である
#         またこの手法は重点サンプリング法にも似たところがある
#         うまく設計すると
#         粒子フィルタはmcmcよりも高速である
#         拡張カルマンフィルタや無香カルマンフィルタ
#         unscented
#         カルマンフィルタ
#         に対して
#         十分なサンプル点があればベイズ最適推定に近付くためにより精度が高くなることから
#         これらの代わりに用いられることがある
#         手法を組み合わせ
#         カルマンフィルタを粒子フィルタの提案分布として使うこともできる
#         파티클
#         필터는
#         보통
#         베이즈
#         모델을
#         추정하기
#         위해
#         사용된다
#         이는
#         잠재변수가
#         마르코프
#         연쇄로
#         서로
#         관련되어
#         있는
#         경우로
#         은닉
#         모델
#         hmm
#         과
#         비슷하지만
#         드러나지
#         않은
#         변수의
#         상태
#         공간이
#         연속적이고
#         정확하게
#         추정할
#         수
#         있을
#         만큼
#         한정적이지
#         않다
#         예를
#         들어
#         선형
#         동적
#         시스템에서는
#         잠재변수의
#         가우스
#         분포에
#         한정되는데
#         따라서
#         정확한
#         추정이
#         효과적으로
#         칼만
#         필터만으로
#         이루어질
#         있다
#         그리고
#         관련된
#         모델의
#         맥락에서
#         보면
#         필터링은
#         어떤
#         특정
#         시간에
#         분포
#         를
#         결정하되
#         관측
#         값은
#         그
#         시간
#         까지만
#         주어진다
#         필터라는
#         이름을
#         얻게된
#         까닭은
#         근사값을
#         아까
#         말한
#         의미에서
#         필터링
#         하는데
#         한
#         무리의
#         다른
#         가중치를
#         가진
#         분포의
#         예
#         입자
#         사용하기
#         때문이다
#       INDEXED! http://eduardoacye.github.io/proyectos/particle.html
#     VISITED http://eduardoacye.github.io/proyectos/recomend.html
#     INDEXING http://eduardoacye.github.io/proyectos/recomend.html
#       INDEXING WORDS FROM URL ID 3
#         forman
#         específico
#         técnica
#         filtro
#         presentan
#         distintos
#         tipos
#         ítems
#         películas
#         música
#         libros
#         noticias
#         imágenes
#         etc
#         usuario
#         particular
#         generalmente
#         recomendador
#         compara
#         perfil
#         características
#         referencia
#         busca
#         predecir
#         ránking
#         ponderación
#         daría
#         ítem
#         aún
#         considerado
#         basarse
#         relación
#         acercamiento
#         ambiente
#         social
#         recommender
#         recommendation
#         sometimes
#         replacing
#         system
#         synonym
#         platform
#         subclass
#         that
#         seek
#         predict
#         rating
#         preference
#         user
#         would
#         give
#         item
#         have
#         become
#         extremely
#         common
#         recent
#         years
#         applied
#         variety
#         applications
#         ones
#         probably
#         movies
#         music
#         news
#         books
#         articles
#         queries
#         tags
#         products
#         general
#         however
#         there
#         also
#         for
#         experts
#         jokes
#         restaurants
#         financial
#         services
#         life
#         insurance
#         persons
#         online
#         dating
#         twitter
#         followers
#         4
#         سامانه
#         توصیه
#         گر
#         به
#         انگلیسی
#         یا
#         پیشنهادگر
#         واژه
#         سیستم
#         گاهی
#         با
#         پلتفرم
#         موتور
#         جایگزین
#         می
#         شود
#         تحلیل
#         رفتار
#         کاربر
#         خود
#         اقدام
#         پیشنهاد
#         مناسب
#         ترین
#         اقلام
#         داده
#         اطلاعات
#         کالا
#         و
#         نماید
#         این
#         رویکردی
#         است
#         که
#         برای
#         مواجهه
#         مشکلات
#         ناشی
#         از
#         حجم
#         فراوان
#         رو
#         رشد
#         ارائه
#         شده
#         کمک
#         کند
#         تا
#         در
#         میان
#         عظیم
#         سریع
#         تر
#         هدف
#         نزدیک
#         شوند
#         برخی
#         را
#         معادل
#         پالایش
#         گروهی
#         collaborative
#         دانند
#       INDEXED! http://eduardoacye.github.io/proyectos/recomend.html
#     VISITED http://eduardoacye.github.io/proyectos/deep.html
#     INDEXING http://eduardoacye.github.io/proyectos/deep.html
#       INDEXING WORDS FROM URL ID 5
#         deep
#         structured
#         hierarchical
#         dl
#         branch
#         on
#         attempt
#         model
#         high
#         level
#         abstractions
#         data
#         using
#         architectures
#         complex
#         structures
#         otherwise
#         composed
#         multiple
#         non
#         linear
#         transformations
#         p198
#         یادگیری
#         عمیق
#         عبارت
#         دیگر
#         ساختار
#         سلسله
#         مراتبی
#         یک
#         زیر
#         شاخه
#         ماشینی
#         اساس
#         آن
#         بر
#         نمایش
#         دانش
#         ویژگی
#         ها
#         لایه
#         های
#         مدل
#         ۱
#         نمونه
#         آموزشی
#         مثال
#         تصویر
#         گربه
#         تواند
#         صورت
#         مختلف
#         نظیر
#         بردار
#         ریاضی
#         پر
#         مقدار
#         ازای
#         هر
#         پیکسل
#         دید
#         کلی
#         شکل
#         مجموعه
#         زیرشکل
#         کوچک
#         اعضای
#         سازی
#         روش
#         باعث
#         ساده
#         شدن
#         فرایند
#         ماشین
#         تشخیص
#         امید
#         جایگزینی
#         استخراج
#         توسط
#         دست
#         بشر
#         مانند
#         کامل
#         خودکار
#         بدون
#         نظارت
#         unsupservised
#         نیمه
#         نظارتی
#         semi
#         supservised
#         وجود
#         دارد
#         ۲
#         انگیزه
#         ی
#         اولیه
#         حوزه
#         طریقه
#         بررسی
#         عصبی
#         مغز
#         انسان
#         الهام
#         گرفته
#         یاخته
#         ارسال
#         پیام
#         یکدیگر
#         ادراک
#         امکان
#         پذیر
#         کنند
#         ۳
#         بسته
#         فرض
#         متفاوت
#         مورد
#         نحوه
#         اتصال
#         مختلفی
#         اند
#         هرچند
#         طبیعی
#         ندارد
#         پیچیدگی
#         بیشتری
#         دارا
#         شبکه
#         neural
#         network
#         پیچیده
#         convolutional
#         باور
#         belief
#         پیشرفت
#         خوبی
#         پردازش
#         زبان
#         ایجاد
#         کرده
#         딥
#         러닝
#         영어
#         은
#         여러
#         비선형
#         변환기법의
#         조합을
#         통해
#         높은
#         수준의
#         추상화
#         다량의
#         데이터나
#         복잡한
#         자료들
#         속에서
#         핵심적인
#         내용
#         또는
#         기능을
#         요약하는
#         작업
#         시도하는
#         기계학습
#         알고리즘의
#         집합
#         으로
#         정의
#         되며
#         큰틀에서
#         사람의
#         사고방식을
#         컴퓨터에게
#         가르치는
#         기계학습의
#         분야라고
#         이야기
#         할
#         глубокое
#         англ
#         набор
#         машинного
#         обучения
#         которые
#         пытаются
#         моделировать
#         высокоуровневые
#         абстракции
#         данных
#         используя
#         архитектуры
#         состоящие
#         нелинейных
#         трансформаций
#       INDEXED! http://eduardoacye.github.io/proyectos/deep.html
#     VISITED http://eduardoacye.github.io/participantes/mois.html
#     INDEXING http://eduardoacye.github.io/participantes/mois.html
#       INDEXING WORDS FROM URL ID 10
#         moises
#         salas
#       INDEXED! http://eduardoacye.github.io/participantes/mois.html
#   DEPTH 2
#   URLs ['http://eduardoacye.github.io/proyectos/particle.html', 'http://eduardoacye.github.io/proyectos/ranking.html', 'http://eduardoacye.github.io/proyectos/deep.html', 'http://eduardoacye.github.io/proyectos/recomend.html']
#     VISITED http://eduardoacye.github.io/proyectos/particle.html
#     VISITED http://eduardoacye.github.io/proyectos/ranking.html
#     VISITED http://eduardoacye.github.io/proyectos/deep.html
#     VISITED http://eduardoacye.github.io/proyectos/recomend.html
#   DEPTH 3
#   URLs []
#   DEPTH 4
#   URLs []
#   DEPTH 5
#   URLs []
#   DEPTH 6
#   URLs []
#   DEPTH 7
#   URLs []
#   DEPTH 8
#   URLs []
#   DEPTH 9
#   URLs []
